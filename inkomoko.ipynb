# %%
import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
# !pip install gspread

# %%
# !pip install --upgrade google-api-python-client oauth2client

# %%
aa_codebook=pd.read_excel("Survey Codebook_revised.xlsx")

# %%
aa_codebook
# Out:
#                    Section                            Survey Question (Label)  \
# 0                      NaN                                                NaN
# 1   A. Client Demographics                                                NaN
# 2                      NaN                           Surveyor/Enumerator name
# 3                      NaN                                             Gender
# 4                      NaN                                  Name/Clients name
# ..                     ...                                                ...
# 94                     NaN  if you are not in a saving group and you are s...
# 95                     NaN                       if other saving mode specify
# 96                     NaN               What is your second income resource?
# 97                     NaN     How much money yourself do you save per month?
# 98                     NaN  Do you feel that there is a change in househol...
#
#              variable name
# ...

# %%
aa_endline_Test_revised=pd.read_excel("Kak_endline_Test_revised.xlsx")

# %%
aa_endline_Test_revised
# Out:
#               unique_id cd_gender cd_nationality                    cd_strata  \
# 0                     7      Male         Kenyan  Host community entrepreneur
# 1                     8    Female         Kenyan  Host community entrepreneur
# 2    PART/KE16012104001      Male      Congolese                      Refugee
# 3    PART/KE16012104002      Male       Sudanese                      Refugee
# 4    PART/KE16012104003    Female         Somali                      Refugee
# ..                  ...       ...            ...                          ...
# 532  PART/KE16012104896    Female         Somali                      Refugee
# 533  PART/KE16012104897    Female         Kenyan                         Host
# 534  PART/KE16012104898      Male         Somali                      Refugee
# 535  PART/KE16012104899    Female         Somali                      Refugee
# 536  PART/KE16012104900    Female         Somali                      Refugee
#
# ...

# %%
aa_Baseline_Test_revised=pd.read_excel("Kak_Baseline_Test_revised.xlsx")

# %%
df=aa_Baseline_Test_revised

# %%
df.is
# Out:
#   File "<ipython-input-1-e5b32670040e>", line 1
#     df.is
#         ^
# SyntaxError: invalid syntax

# %%
import pyodbc
import pandas as pd
# Connection to db
sql_conn = pyodbc.connect(Trusted_Connection='Yes', DRIVER='{SQL Server}', SERVER='IT-MAXIMET\TSTDB', DATABASE='TestDB',\
                      UID='testdba', PWD='testdba')

# %%
dfi = pd.read_sql("select * from [TESTDB].[info]", sql_conn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-7cbaf1a40700> in <module>
# ----> 1 dfi = pd.read_sql("select * from [TESTDB].[info]")
#
# TypeError: 'tuple' object is not callable

# %%
sql_conn

# %%
import pymysql
import pandas as pd
conni=pymysql.connect(host='localhost',port=int(3306),user='root',passwd='maxo',db='test_INKOMOKO_db')

#dfii=pd.read_sql_query("SELECT * FROM collations limit 2",conni)

#print(dfii)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="maxo"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE test_INKOMOKO_db")

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

mydb = mysql.connector.connect(
 host="localhost",
  user="root",
  password="maxo"
)

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
# ('test_inkomoko_db',)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="maxo",
  database="test_INKOMOKO_db"
)

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="maxo",
database="test_inkomoko_db"
)
mycursor = mydb.cursor() 
mycursor.execute('create table baseline
('
uid	                           int primary key,
bd_earner_only                  varchar(250),
bd_members_respfor				varchar(250),
bd_bizsector					varchar(250),
e_total_employees				varchar(250),
e_fulltime_employees			varchar(250),
e_parttime_employees			varchar(250),
e_casual_employees				varchar(250),
e_male_employees				varchar(250),
e_female_employees				varchar(250),
e_related_employees				varchar(250),
e_refugees_employees			varchar(250),
Howmanyemployeesarefromthe		varchar(250),
sr_bank_account					varchar(250),
sr_pri_inc_sourcs				varchar(250),
sr_access_newfunds				varchar(250),
IfYesinQ31howhaveyouacce		varchar(250),
sr_access						varchar(250),
sr_access_1						varchar(250),
sr_access_2						varchar(250),
sr_access_3						varchar(250),
sr_access_4						varchar(250),
sr_access_5						varchar(250),
sr_access_6						varchar(250),
sr_access_7						varchar(250),
sr_access_8						varchar(250),
sr_access_9						varchar(250),
sr_access_no					varchar(250),
Onaveragehowmanycustomersd		varchar(250),
sr_customers_hwmny				varchar(250),
OUTLIERCHECKONTHENUMBEROFC		varchar(250),
sr_customers_main				varchar(250),
sr_records_keepb				varchar(250),
sr_mnthly_sales_total			varchar(250),
OUTLIERCHECKONTHEAVERAGEMON		varchar(250),
sr_fluctuations					varchar(250),
sr_revstreams_most				varchar(250),
sr_revstreams_least				varchar(250),
BI								varchar(250),
BJ								varchar(250),
BK								varchar(250),
BL								varchar(250),
Onascaleof1to5where1me			varchar(250),
knwrate_sales					varchar(250),
knwrate_ops_mgt					varchar(250),
knwrate_invent_mgt				varchar(250),
knwrate_bkeeping				varchar(250),
knwrate_cashflow				varchar(250),
skill_imprv1					varchar(250),
skill_imprv2	s				varchar(250),
kill_imprv3	skill_imprv4		varchar(250),
Howmanymealsdoesyourhouseho		varchar(250),
liv_meals_number_base			varchar(250),
Inthelast4monthsdidyoubu		varchar(250),
liv_assetsbght_4mnths			varchar(250),
liv_cookingfuel	CB				varchar(250),
CC	liv_expnseschl_3mnths		varchar(250),
liv_expnsecooking				varchar(250),
liv_expnsehhclthng				varchar(250),
liv_expnserent					varchar(250),
liv_expnsetrans_comm			varchar(250),
aec_knowledge					varchar(250))')'
# Out:
#   File "<ipython-input-30-b39cafe07c49>", line 8
#     mycursor.execute('create table baseline
#                                            ^
# SyntaxError: EOL while scanning string literal

# %%
model.export_srcpkg(platform, toolchain, "mymodel_pkg.zip", "mymodel.dylib")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f8a597c8649e> in <module>
# ----> 1 model.export_srcpkg(platform, toolchain, "mymodel_pkg.zip", "mymodel.dylib")
#
# NameError: name 'model' is not defined

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="maxo",
database="test_INKOMOKO_db"
)

# %%
mycursor = mydb.cursor()
mycursor.execute("create table baseline (
uid int primarykey,
bd_earner_only varchar(250),
bd_members_respfor varchar(250),
bd_bizsector varchar(250),
e_total_employees varchar(250),
e_fulltime_employees varchar(250),
e_parttime_employees varchar(250),
e_casual_employees varchar(250),
e_male_employees varchar(250),
e_female_employees varchar(250),
e_related_employees varchar(250),
e_refugees_employees varchar(250),
Howmanyemployeesarefromthe	varchar(250),
sr_bank_account	varchar(250),
sr_pri_inc_sourcs varchar(250),
sr_access_newfunds varchar(250),
IfYesinQ31howhaveyouacce varchar(250),
sr_access	varchar(250),
sr_access_1	varchar(250),
sr_access_2	varchar(250),
sr_access_3	varchar(250),
sr_access_4	varchar(250),
sr_access_5	varchar(250),
sr_access_6	varchar(250),
sr_access_7	varchar(250),
sr_access_8	varchar(250),
sr_access_9	varchar(250),
sr_access_no varchar(250),
Onaveragehowmanycustomersd varchar(250),
sr_customers_hwmny varchar(250),
OUTLIERCHECKONTHENUMBEROFC varchar(250),
sr_customers_main varchar(250),
sr_records_keepb varchar(250),
sr_mnthly_sales_total varchar(250),
OUTLIERCHECKONTHEAVERAGEMON	 varchar(250),
sr_fluctuations	 varchar(250),
sr_revstreams_most varchar(250),
sr_revstreams_least	varchar(250),
BI varchar(250),
BJ varchar(250),
BK varchar(250),
BL varchar(250),
Onascaleof1to5where1me varchar(250),
knwrate_sales varchar(250),
knwrate_ops_mgt	varchar(250),
knwrate_invent_mgt	varchar(250),
knwrate_bkeeping varchar(250),
knwrate_cashflowvarchar(250),
skill_imprv1 varchar(250),
skill_imprv2 varchar(250),
skill_imprv3 varchar(250),
skill_imprv4 varchar(250),
Howmanymealsdoesyourhouseho	varchar(250),
liv_meals_number_base varchar(250),
Inthelast4monthsdidyoubu varchar(250),
liv_assetsbght_4mnths varchar(250),
liv_cookingfuel	CB varchar(250),
CC	liv_expnseschl_3mnths varchar(250),
liv_expnsecooking varchar(250),
liv_expnsehhclthng varchar(250),
liv_expnserent varchar(250),
liv_expnsetrans_comm varchar(250),
aec_knowledge varchar(250)");
# Out:
#   File "<ipython-input-28-066d1690a050>", line 8
#     mycursor.execute("create table baseline (
#                                              ^
# SyntaxError: EOL while scanning string literal
